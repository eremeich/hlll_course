# %% [markdown]
# <a href="https://colab.research.google.com/github/eremeich/hlll_course/blob/master/NLP_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Natural Language Processing (NLP)
#
# *   Classification
# *   Detction
# *   Scoring
# *   Summary
# *   Meaning
# *   Entity Extraction
# *   Recomendations
# *   Syntax & text quality (spell checking)
# *   Generative models:
#  *   image descriptions
#  *   poetry generation
#  *   sentenses
# * ...
#
# ---
# Text is sequnse of symbols with some primitives.
#
# Tokenisation (e.g. by spaces/punctuation)
#
#
#
# Example:
# ```
# People are strange.
# ```
# Normalisation:
# ```
# Human be strange
# ```
# Structure:
#
# ```
# Noun Verb Adjective
# ```
#
# Syntax parsing, try it [spacy](https://spacy.io) and [syntaxnet](https://https://opensource.google/projects/syntaxnet)
#
#
#
# ---
#
#
#
#   Task
# A Good Part-of-Speech Tagger in about 200 Lines of Python
# September 18, 2013 · by Matthew Honnibal
# https://explosion.ai/blog/part-of-speech-pos-tagger-in-python
#
#
# capstone
# dataset of sentences
# keras/tensorflow/sklearn realise notebook with evaluation
#
# Predic Nouns/adj/verbs/punctuation/etc for each word
#
# 1.   Dataset (Ontonotes5)
# 2.   Preproc
# 3.   Honnibals code understanding
# 4.   Run (optional)
# 5.   Predict any sentences
#
# Create vector
